# %% [markdown]
# ## Basic plots (most common)
#
# - Scatter plot
# - Line plot (scatter with lines)
# - Bar chart
# - Histogram
# - Box plot
# - Violin plot
# - Area plot

# %%
import numpy as np
import pandas as pd
import plotly.express as px
